# %%
cd MoEv/
# Out:
# /home/jovyan/MoEv

# %%
# !python3 -W ignore Start.py -t netflow
# Out:
# 2022-09-27 12:13:01,090: INFO - Moev.py started
# Pred. Time: 0.19722056185968595µs
#
#
# 			SGD_Classifier.joblib
#
#
#
# Accuracy for model is: 0.962851
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0   0.999698  0.925983  0.961430     28615
#            1   0.931064  0.999720  0.964171     28614
#
#     accuracy                       0.962851     57229
#    macro avg   0.965381  0.962852  0.962800     57229
# weighted avg   0.965382  0.962851  0.962800     57229
#
#
# Confusion Matrix:
#
# [[26497  2118]
#  [    8 28606]]
#
#
#
# Cohen Kappa Score:
#
# 0.9257020999378394
#
# Matthews Corrcoef
#
# 0.928229117302508
#
# ##########################################################
# Pred. Time: 3.9999571128015607µs
#
#
# 			Random_Forest_Classifier.joblib
#
#
#
# Accuracy for model is: 0.840623
#
# Classification report:
#
#               precision    recall  f1-score   support
#
# ...
