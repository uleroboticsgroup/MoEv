# %%
cd MoEv/
# Out:
# /home/jovyan/MoEv

# %%
"Results testing BoT dataset"
# Out:
# 'Results testing BoT dataset'

# %%
# !python3 -W ignore Start.py -t netflow && sed -i "s/dataset_bot_service_1000_limpio.csv/netflow_production_50-50_limpio.csv/g" ./conf.yaml
# Out:
# 2023-01-11 12:37:31,349: INFO - Moev.py started
# Pred. Time: 1.0379870026384543µs
#
#
# 			Logistic_Regression_Classifier.joblib
#
#
#
# Accuracy for model is: 0.584422
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0   0.592497  0.540774  0.565455      3826
#            1   0.577644  0.628071  0.601803      3826
#
#     accuracy                       0.584422      7652
#    macro avg   0.585071  0.584422  0.583629      7652
# weighted avg   0.585071  0.584422  0.583629      7652
#
#
# Confusion Matrix:
#
# [[2069 1757]
#  [1423 2403]]
#
#
#
# Cohen Kappa Score:
#
# 0.1688447464715107
#
# Matthews Corrcoef
#
# 0.1694918168793819
#
# ##########################################################
# Pred. Time: 0.8908292727512772µs
#
#
# 			MLP_Regressor_Classifier.joblib
#
#
#
# Accuracy for model is: 0.835076
#
# Classification report:
#
#               precision    recall  f1-score   support
#
# ...

# %%
"Results testing D7"
# Out:
# 'Results testing D7'

# %%
# !python3 -W ignore Start.py -t netflow && sed -i "s/netflow_production_50-50_limpio.csv/dataset_sampling_10000_test.csv/g" ./conf.yaml && sed -i "s+./models/1000/+./models/10000/+g" ./conf.yaml
# Out:
# 2023-01-11 12:38:55,662: INFO - Moev.py started
# Pred. Time: 1.485969709313434µs
#
#
# 			Logistic_Regression_Classifier.joblib
#
#
#
# Accuracy for model is: 0.560870
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0   0.541543  0.793478  0.643739       460
#            1   0.613821  0.328261  0.427762       460
#
#     accuracy                       0.560870       920
#    macro avg   0.577682  0.560870  0.535751       920
# weighted avg   0.577682  0.560870  0.535751       920
#
#
# Confusion Matrix:
#
# [[365  95]
#  [309 151]]
#
#
#
# Cohen Kappa Score:
#
# 0.12173913043478257
#
# Matthews Corrcoef
#
# 0.1375278093252286
#
# ##########################################################
# Pred. Time: 11.17768494979195µs
#
#
# 			MLP_Regressor_Classifier.joblib
#
#
#
# Accuracy for model is: 0.921739
#
# Classification report:
#
#               precision    recall  f1-score   support
#
# ...

# %%
"Results Sampling 10000"
# Out:
# 'Results Sampling 10000'

# %%
# !python3 -W ignore Start.py -t netflow && sed -i "s/dataset_sampling_10000_test.csv/netflow_sampling_1000_50-50_test_limpio.csv/g" ./conf.yaml && sed -i "s+./models/10000/+./models/1000/+g" ./conf.yaml
# Out:
# 2023-01-11 12:39:24,922: INFO - Moev.py started
# Pred. Time: 2.161686464866496µs
#
#
# 			Logistic_Regression_Classifier.joblib
#
#
#
# Accuracy for model is: 0.585404
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0   0.591362  0.552795  0.571429       322
#            1   0.580175  0.618012  0.598496       322
#
#     accuracy                       0.585404       644
#    macro avg   0.585769  0.585404  0.584962       644
# weighted avg   0.585769  0.585404  0.584962       644
#
#
# Confusion Matrix:
#
# [[178 144]
#  [123 199]]
#
#
#
# Cohen Kappa Score:
#
# 0.1708074534161491
#
# Matthews Corrcoef
#
# 0.17117186465904607
#
# ##########################################################
# Pred. Time: 2.3456834117818324µs
#
#
# 			MLP_Regressor_Classifier.joblib
#
#
#
# Accuracy for model is: 0.805901
#
# Classification report:
#
#               precision    recall  f1-score   support
#
# ...

# %%
"Results Sampling 1000"
# Out:
# 'Results Sampling 1000'

# %%
# !python3 -W ignore Start.py -t netflow && sed -i "s/netflow_sampling_1000_50-50_test_limpio.csv/netflow_sampling_500_50-50_test_limpio.csv/g" ./conf.yaml && sed -i "s+./models/1000/+./models/500/+g" ./conf.yaml
# Out:
# 2023-01-11 12:44:10,519: INFO - Moev.py started
# Pred. Time: 0.8434755551661854µs
#
#
# 			Logistic_Regression_Classifier.joblib
#
#
#
# Accuracy for model is: 0.520030
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0   0.519414  0.535903  0.527530      1323
#            1   0.520687  0.504157  0.512289      1323
#
#     accuracy                       0.520030      2646
#    macro avg   0.520050  0.520030  0.519909      2646
# weighted avg   0.520050  0.520030  0.519909      2646
#
#
# Confusion Matrix:
#
# [[709 614]
#  [656 667]]
#
#
#
# Cohen Kappa Score:
#
# 0.04006046863189716
#
# Matthews Corrcoef
#
# 0.04008067058407983
#
# ##########################################################
# Pred. Time: 1.0226949632663396µs
#
#
# 			MLP_Regressor_Classifier.joblib
#
#
#
# Accuracy for model is: 0.911187
#
# Classification report:
#
#               precision    recall  f1-score   support
#
# ...

# %%
"Results Sampling 500"
# Out:
# 'Results Sampling 500'

# %%
# !python3 -W ignore Start.py -t netflow && sed -i "s/netflow_sampling_500_50-50_test_limpio.csv/netflow_sampling_250_50-50_test_limpio.csv/g" ./conf.yaml && sed -i "s+./models/500/+./models/250/+g" ./conf.yaml
# Out:
# 2023-01-11 12:45:24,367: INFO - Moev.py started
# Pred. Time: 0.8275144302149942µs
#
#
# 			Logistic_Regression_Classifier.joblib
#
#
#
# Accuracy for model is: 0.631830
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0   0.575924  1.000000  0.730903      2727
#            1   1.000000  0.263660  0.417295      2727
#
#     accuracy                       0.631830      5454
#    macro avg   0.787962  0.631830  0.574099      5454
# weighted avg   0.787962  0.631830  0.574099      5454
#
#
# Confusion Matrix:
#
# [[2727    0]
#  [2008  719]]
#
#
#
# Cohen Kappa Score:
#
# 0.2636596993032636
#
# Matthews Corrcoef
#
# 0.3896767132712607
#
# ##########################################################
# Pred. Time: 0.9762309696545827µs
#
#
# 			MLP_Regressor_Classifier.joblib
#
#
#
# Accuracy for model is: 0.939311
#
# Classification report:
#
#               precision    recall  f1-score   support
#
# ...

# %%
"Results Sampling 250"
# Out:
# 'Results Sampling 250'

# %%
# !python3 -W ignore Start.py -t netflow
# Out:
# 2023-01-11 12:45:59,045: INFO - Moev.py started
# Pred. Time: 3.8631317418955775µs
#
#
# 			MLP_Regressor_Classifier.joblib
#
#
#
# Accuracy for model is: 0.968347
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0   0.969837  0.966761  0.968297      9146
#            1   0.966866  0.969932  0.968397      9146
#
#     accuracy                       0.968347     18292
#    macro avg   0.968352  0.968347  0.968347     18292
# weighted avg   0.968352  0.968347  0.968347     18292
#
#
# Confusion Matrix:
#
# [[8842  304]
#  [ 275 8871]]
#
#
#
# Cohen Kappa Score:
#
# 0.9366936365624317
#
# Matthews Corrcoef
#
# 0.9366983452996103
#
# ##########################################################
# Pred. Time: 0.1422404304469359µs
#
#
# 			SGD_Classifier.joblib
#
#
#
# Accuracy for model is: 0.998633
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0   0.997817  0.999453  0.998634      9146
# ...
