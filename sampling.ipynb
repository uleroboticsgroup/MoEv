# %%
cd MoEv/
# Out:
# /home/jovyan/MoEv

# %%
"Results Sampling 250"
# Out:
# 'Results Sampling 250'

# %%
# !python3 -W ignore Start.py -t netflow && sed -i "s/netflow_sampling_250_50-50_test_limpio.csv/netflow_sampling_500_50-50_test_limpio.csv/g" ./conf.yaml && sed -i "s+./models/250/+./models/500/+g" ./conf.yaml
# Out:
# 2022-12-30 12:51:50,993: INFO - Moev.py started
# Pred. Time: 0.814531240263919µs
#
#
# 			MLP_Regressor_Classifier.joblib
#
#
#
# Accuracy for model is: 0.959479
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0   0.965453  0.953062  0.959218      2727
#            1   0.953657  0.965897  0.959738      2727
#
#     accuracy                       0.959479      5454
#    macro avg   0.959555  0.959479  0.959478      5454
# weighted avg   0.959555  0.959479  0.959478      5454
#
#
# Confusion Matrix:
#
# [[2599  128]
#  [  93 2634]]
#
#
#
# Cohen Kappa Score:
#
# 0.918958562522919
#
# Matthews Corrcoef
#
# 0.9190342606971879
#
# ##########################################################
# Pred. Time: 0.41769151509267133µs
#
#
# 			SGD_Classifier.joblib
#
#
#
# Accuracy for model is: 0.500000
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0   0.500000  1.000000  0.666667      2727
# ...

# %%
"Results Sampling 500"
# Out:
# 'Results Sampling 500'

# %%
# !python3 -W ignore Start.py -t netflow && sed -i "s/netflow_sampling_500_50-50_test_limpio.csv/netflow_sampling_1000_50-50_test_limpio.csv/g" ./conf.yaml && sed -i "s+./models/500/+./models/1000/+g" ./conf.yaml
# Out:
# 2022-12-30 12:53:12,733: INFO - Moev.py started
# Pred. Time: 1.151263604550559µs
#
#
# 			Logistic_Regression_Classifier.joblib
#
#
#
# Accuracy for model is: 0.631830
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0   0.575924  1.000000  0.730903      2727
#            1   1.000000  0.263660  0.417295      2727
#
#     accuracy                       0.631830      5454
#    macro avg   0.787962  0.631830  0.574099      5454
# weighted avg   0.787962  0.631830  0.574099      5454
#
#
# Confusion Matrix:
#
# [[2727    0]
#  [2008  719]]
#
#
#
# Cohen Kappa Score:
#
# 0.2636596993032636
#
# Matthews Corrcoef
#
# 0.3896767132712607
#
# ##########################################################
# Pred. Time: 0.8730211667101768µs
#
#
# 			MLP_Regressor_Classifier.joblib
#
#
#
# Accuracy for model is: 0.939311
#
# Classification report:
#
#               precision    recall  f1-score   support
#
# ...

# %%
"Results Sampling 1000"
# Out:
# 'Results Sampling 1000'

# %%
# !python3 -W ignore Start.py -t netflow && sed -i "s/netflow_sampling_1000_50-50_test_limpio.csv/netflow_production_50-50_limpio.csv/g" ./conf.yaml
# Out:
# 2022-12-30 12:54:19,435: INFO - Moev.py started
# Pred. Time: 1.3671674605850368µs
#
#
# 			Logistic_Regression_Classifier.joblib
#
#
#
# Accuracy for model is: 0.520030
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0   0.519414  0.535903  0.527530      1323
#            1   0.520687  0.504157  0.512289      1323
#
#     accuracy                       0.520030      2646
#    macro avg   0.520050  0.520030  0.519909      2646
# weighted avg   0.520050  0.520030  0.519909      2646
#
#
# Confusion Matrix:
#
# [[709 614]
#  [656 667]]
#
#
#
# Cohen Kappa Score:
#
# 0.04006046863189716
#
# Matthews Corrcoef
#
# 0.04008067058407983
#
# ##########################################################
# Pred. Time: 1.0465728632897386µs
#
#
# 			MLP_Regressor_Classifier.joblib
#
#
#
# Accuracy for model is: 0.911187
#
# Classification report:
#
#               precision    recall  f1-score   support
#
# ...

# %%
"Results testing D7"
# Out:
# 'Results testing D7'

# %%
# !python3 -W ignore Start.py -t netflow && sed -i "s/netflow_production_50-50_limpio.csv/dataset_bot_service_1000_limpio.csv/g" ./conf.yaml
# Out:
# 2022-12-30 12:55:21,724: INFO - Moev.py started
# Pred. Time: 1.437767692234205µs
#
#
# 			Logistic_Regression_Classifier.joblib
#
#
#
# Accuracy for model is: 0.560870
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0   0.541543  0.793478  0.643739       460
#            1   0.613821  0.328261  0.427762       460
#
#     accuracy                       0.560870       920
#    macro avg   0.577682  0.560870  0.535751       920
# weighted avg   0.577682  0.560870  0.535751       920
#
#
# Confusion Matrix:
#
# [[365  95]
#  [309 151]]
#
#
#
# Cohen Kappa Score:
#
# 0.12173913043478257
#
# Matthews Corrcoef
#
# 0.1375278093252286
#
# ##########################################################
# Pred. Time: 1.6901804053265117µs
#
#
# 			MLP_Regressor_Classifier.joblib
#
#
#
# Accuracy for model is: 0.921739
#
# Classification report:
#
#               precision    recall  f1-score   support
#
# ...

# %%
"Results testing BoT dataset"
# Out:
# 'Results testing BoT dataset'

# %%
# !python3 -W ignore Start.py -t netflow
# Out:
# 2022-12-30 12:57:04,450: INFO - Moev.py started
# Pred. Time: 0.3568800842955171µs
#
#
# 			Logistic_Regression_Classifier.joblib
#
#
#
# Accuracy for model is: 0.584422
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0   0.592497  0.540774  0.565455      3826
#            1   0.577644  0.628071  0.601803      3826
#
#     accuracy                       0.584422      7652
#    macro avg   0.585071  0.584422  0.583629      7652
# weighted avg   0.585071  0.584422  0.583629      7652
#
#
# Confusion Matrix:
#
# [[2069 1757]
#  [1423 2403]]
#
#
#
# Cohen Kappa Score:
#
# 0.1688447464715107
#
# Matthews Corrcoef
#
# 0.1694918168793819
#
# ##########################################################
# Pred. Time: 0.7849554708972379µs
#
#
# 			MLP_Regressor_Classifier.joblib
#
#
#
# Accuracy for model is: 0.835076
#
# Classification report:
#
#               precision    recall  f1-score   support
#
# ...
