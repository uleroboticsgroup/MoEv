# %% [markdown]
# # Detecting SQL Injection Attacks in Flow-Based Networks: A Comparative Analysis of Deep Learning and Traditional Approaches in Sampled and Unsampled Flow Data

# %% [markdown]
# ## Results without packet sampling
#
# ### Dataset D2

# %%
# %cd MoEv/
# Out:
# /home/alberto/Papers/Paper SQLia/MoEv/MoEv

# %%
# !python3 -W ignore Start.py -t netflow && sed -i "s/D2testSql_normalized.csv/D3testSql_normalized.csv/g" ./conf.yaml
# Out:
# 2026-03-18 12:59:06,995: INFO - Moev.py started
# Pred. Time: 31.253568267382327µs
#
#
# 			Voting_Classifier_BEST.joblib
#
#
#
# Accuracy for model is: 0.975589
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0   0.994333  0.956631  0.975118     28615
#            1   0.958214  0.994548  0.976043     28614
#
#     accuracy                       0.975589     57229
#    macro avg   0.976274  0.975590  0.975581     57229
# weighted avg   0.976274  0.975589  0.975581     57229
#
#
# Confusion Matrix:
#
# [[27374  1241]
#  [  156 28458]]
#
#
#
# Cohen Kappa Score:
#
# 0.9511786305954626
#
# Matthews Corrcoef
#
# 0.9518631523968126
#
# FAR Metric:
#
# 0.043368862484710814
#
# ##########################################################
# Pred. Time: 1.6295151036527522µs
#
#
# 			Random_Forest_Classifier_BEST.joblib
#
#
#
# Accuracy for model is: 0.838019
#
# Classification report:
#
#               precision    recall  f1-score   support
# ...

# %% [markdown]
# ### Dataset D3

# %%
# !python3 -W ignore Start.py -t netflow && sed -i "s/D3testSql_normalized.csv/D5testSql_normalized.csv/g" ./conf.yaml && sed -i "s/without-sampling/sampling/g" ./conf.yaml
# Out:
# 2026-03-18 12:59:12,800: INFO - Moev.py started
# Pred. Time: 84.50216717190213µs
#
#
# 			Voting_Classifier_BEST.joblib
#
#
#
# Accuracy for model is: 0.944444
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0   0.900000  1.000000  0.947368        90
#            1   1.000000  0.888889  0.941176        90
#
#     accuracy                       0.944444       180
#    macro avg   0.950000  0.944444  0.944272       180
# weighted avg   0.950000  0.944444  0.944272       180
#
#
# Confusion Matrix:
#
# [[90  0]
#  [10 80]]
#
#
#
# Cohen Kappa Score:
#
# 0.8888888888888888
#
# Matthews Corrcoef
#
# 0.8944271909999159
#
# FAR Metric:
#
# 0.0
#
# ##########################################################
# Pred. Time: 15.903843773735893µs
#
#
# 			Random_Forest_Classifier_BEST.joblib
#
#
#
# Accuracy for model is: 0.694444
#
# Classification report:
#
#               precision    recall  f1-score   support
#
# ...

# %% [markdown]
# ### Dataset D5

# %%
# !python3 -W ignore Start.py -t netflow && sed -i "s/D5testSql_normalized.csv/D7testSql_normalized.csv/g" ./conf.yaml && sed -i "s/sampling/sampling-500/g" ./conf.yaml
# Out:
# 2026-03-18 12:59:14,441: INFO - Moev.py started
# Pred. Time: 90.97781192099266µs
#
#
# 			Voting_Classifier_BEST.joblib
#
#
#
# Accuracy for model is: 0.609481
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0   0.666667  0.437923  0.528610       886
#            1   0.581513  0.781038  0.666667       886
#
#     accuracy                       0.609481      1772
#    macro avg   0.624090  0.609481  0.597639      1772
# weighted avg   0.624090  0.609481  0.597639      1772
#
#
# Confusion Matrix:
#
# [[388 498]
#  [194 692]]
#
#
#
# Cohen Kappa Score:
#
# 0.218961625282167
#
# Matthews Corrcoef
#
# 0.23311314140279152
#
# FAR Metric:
#
# 0.5620767494356659
#
# ##########################################################
# Pred. Time: 2.958839149561208µs
#
#
# 			Random_Forest_Classifier_BEST.joblib
#
#
#
# Accuracy for model is: 0.489278
#
# Classification report:
#
#               precision    recall  f1-score   support
#
# ...

# %% [markdown]
# ### Dataset D7

# %%
# !python3 -W ignore Start.py -t netflow && sed -i "s/D7testSql_normalized.csv/D2testSql_normalized.csv/g" ./conf.yaml && sed -i "s/sampling-500/without-sampling/g" ./conf.yaml
# Out:
# 2026-03-18 12:59:16,406: INFO - Moev.py started
# Pred. Time: 15.985780429345954µs
#
#
# 			Voting_Classifier_BEST.joblib
#
#
#
# Accuracy for model is: 0.456246
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0   0.458740  0.486471  0.472199      1737
#            1   0.453431  0.426022  0.439299      1737
#
#     accuracy                       0.456246      3474
#    macro avg   0.456086  0.456246  0.455749      3474
# weighted avg   0.456086  0.456246  0.455749      3474
#
#
# Confusion Matrix:
#
# [[845 892]
#  [997 740]]
#
#
#
# Cohen Kappa Score:
#
# -0.08750719631548654
#
# Matthews Corrcoef
#
# -0.08766751529717909
#
# FAR Metric:
#
# 0.5135290731145653
#
# ##########################################################
# Pred. Time: 1.1867398013310935µs
#
#
# 			Random_Forest_Classifier_BEST.joblib
#
#
#
# Accuracy for model is: 0.447035
#
# Classification report:
#
#               precision    recall  f1-score   support
#
# ...
