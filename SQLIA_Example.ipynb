# %% [markdown]
# # Detecting SQL Injection Attacks in Flow-Based Networks: A Comparative Analysis of Deep Learning and Traditional Approaches in Sampled and Unsampled Flow Data

# %% [markdown]
# ## Results without packet sampling
#
# ### Dataset D3

# %%
cd MoEv/
# Out:
# [Errno 2] No such file or directory: 'MoEv/'
# /home/alberto/Papers/Paper SQLia/MoEv/MoEv

# %%
# !python3 -W ignore Start.py -t netflow && sed -i "s/D2testSqlNormalized.csv/D3testSqlNormalized.csv/g" ./conf.yaml
# Out:
# 2025-09-05 09:47:00,403: INFO - Moev.py started
# Pred. Time: 0.02725426522361778µs
#
#
# 			LinearSVC.joblib
#
#
#
# Accuracy for model is: 0.833808
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0   0.993287  0.672165  0.801767     28615
#            1   0.752251  0.995457  0.856932     28614
#
#     accuracy                       0.833808     57229
#    macro avg   0.872769  0.833811  0.829350     57229
# weighted avg   0.872771  0.833808  0.829349     57229
#
#
# Confusion Matrix:
#
# [[19234  9381]
#  [  130 28484]]
#
#
#
# Cohen Kappa Score:
#
# 0.6676179463649876
#
# Matthews Corrcoef
#
# 0.70550500631891
#
# ##########################################################
# Pred. Time: 0.4273195494522964µs
#
#
# 			MLP_Regressor_Classifier.joblib
#
#
#
# Accuracy for model is: 0.994636
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0   0.999859  0.989411  0.994608     28615
# ...

# %% [markdown]
# ### Dataset D3

# %%
# !python3 -W ignore Start.py -t netflow && sed -i "s/D3testSqlNormalized.csv/D5testSqlNormalized.csv/g" ./conf.yaml
# Out:
# 2025-09-05 09:47:04,860: INFO - Moev.py started
# Pred. Time: 2.277031373441889µs
#
#
# 			LinearSVC.joblib
#
#
#
# Accuracy for model is: 0.657303
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0   0.611570  0.840909  0.708134        88
#            1   0.754386  0.477778  0.585034        90
#
#     accuracy                       0.657303       178
#    macro avg   0.682978  0.659343  0.646584       178
# weighted avg   0.683780  0.657303  0.645892       178
#
#
# Confusion Matrix:
#
# [[74 14]
#  [47 43]]
#
#
#
# Cohen Kappa Score:
#
# 0.31736451653464093
#
# Matthews Corrcoef
#
# 0.34150466987795286
#
# ##########################################################
# Pred. Time: 3.6954879760742188µs
#
#
# 			MLP_Regressor_Classifier.joblib
#
#
#
# Accuracy for model is: 0.994382
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0   1.000000  0.988636  0.994286        88
# ...

# %% [markdown]
# ### Dataset D5

# %%
# !python3 -W ignore Start.py -t netflow
# Out:
# 2025-09-05 09:47:06,513: INFO - Moev.py started
# Pred. Time: 0.5345581347463362µs
#
#
# 			LinearSVC.joblib
#
#
#
# Accuracy for model is: 0.496614
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0   0.497875  0.793454  0.611836       886
#            1   0.491667  0.199774  0.284109       886
#
#     accuracy                       0.496614      1772
#    macro avg   0.494771  0.496614  0.447973      1772
# weighted avg   0.494771  0.496614  0.447973      1772
#
#
# Confusion Matrix:
#
# [[703 183]
#  [709 177]]
#
#
#
# Cohen Kappa Score:
#
# -0.006772009029345272
#
# Matthews Corrcoef
#
# -0.008415552848449262
#
# ##########################################################
# Pred. Time: 3.3550822169732295µs
#
#
# 			MLP_Regressor_Classifier.joblib
#
#
#
# Accuracy for model is: 0.939052
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0   0.992405  0.884876  0.935561       886
# ...
