# %% [markdown]
# # Detecting SQL Injection Attacks in Flow-Based Networks: A Comparative Analysis of Deep Learning and Traditional Approaches in Sampled and Unsampled Flow Data

# %% [markdown]
# ## Results without packet sampling
#
# ### Dataset D2

# %%
# %cd MoEv/
# Out:
# /home/alberto/Papers/Paper SQLia/MoEv/MoEv

# %%
# !python3 -W ignore Start.py -t netflow && sed -i "s/D2testSqlNormalized.csv/D3testSqlNormalized.csv/g" ./conf.yaml
# Out:
# 2025-09-24 12:52:03,284: INFO - Moev.py started
# Pred. Time: 0.031757759675884796µs
#
#
# 			LinearSVC.joblib
#
#
#
# Accuracy for model is: 0.833808
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0   0.993287  0.672165  0.801767     28615
#            1   0.752251  0.995457  0.856932     28614
#
#     accuracy                       0.833808     57229
#    macro avg   0.872769  0.833811  0.829350     57229
# weighted avg   0.872771  0.833808  0.829349     57229
#
#
# Confusion Matrix:
#
# [[19234  9381]
#  [  130 28484]]
#
#
#
# Cohen Kappa Score:
#
# 0.6676179463649876
#
# Matthews Corrcoef
#
# 0.70550500631891
#
# ##########################################################
# Pred. Time: 0.4436921056016112µs
#
#
# 			MLP_Regressor_Classifier.joblib
#
#
#
# Accuracy for model is: 0.994636
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0   0.999859  0.989411  0.994608     28615
# ...

# %% [markdown]
# ### Dataset D3

# %%
# !python3 -W ignore Start.py -t netflow && sed -i "s/D3testSqlNormalized.csv/D5testSqlNormalized.csv/g" ./conf.yaml && sed -i "s/without-sampling/sampling/g" ./conf.yaml
# Out:
# 2025-09-24 12:52:07,951: INFO - Moev.py started
# Pred. Time: 2.2783708036615606µs
#
#
# 			LinearSVC.joblib
#
#
#
# Accuracy for model is: 0.657303
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0   0.611570  0.840909  0.708134        88
#            1   0.754386  0.477778  0.585034        90
#
#     accuracy                       0.657303       178
#    macro avg   0.682978  0.659343  0.646584       178
# weighted avg   0.683780  0.657303  0.645892       178
#
#
# Confusion Matrix:
#
# [[74 14]
#  [47 43]]
#
#
#
# Cohen Kappa Score:
#
# 0.31736451653464093
#
# Matthews Corrcoef
#
# 0.34150466987795286
#
# ##########################################################
# Pred. Time: 3.542792931031645µs
#
#
# 			MLP_Regressor_Classifier.joblib
#
#
#
# Accuracy for model is: 0.994382
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0   1.000000  0.988636  0.994286        88
# ...

# %% [markdown]
# ### Dataset D5

# %%
# !python3 -W ignore Start.py -t netflow && sed -i "s/D5testSqlNormalized.csv/D2testSqlNormalized.csv/g" ./conf.yaml && sed -i "s/sampling/without-sampling/g" ./conf.yaml
# Out:
# 2025-09-24 12:52:09,597: INFO - Moev.py started
# Pred. Time: 0.5196233366197711µs
#
#
# 			LinearSVC.joblib
#
#
#
# Accuracy for model is: 0.444695
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0   0.469298  0.845372  0.603546       886
#            1   0.221591  0.044018  0.073446       886
#
#     accuracy                       0.444695      1772
#    macro avg   0.345445  0.444695  0.338496      1772
# weighted avg   0.345445  0.444695  0.338496      1772
#
#
# Confusion Matrix:
#
# [[749 137]
#  [847  39]]
#
#
#
# Cohen Kappa Score:
#
# -0.11060948081264099
#
# Matthews Corrcoef
#
# -0.18490697691445487
#
# ##########################################################
# Pred. Time: 0.33327472936488167µs
#
#
# 			MLP_Regressor_Classifier.joblib
#
#
#
# Accuracy for model is: 0.940745
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0   0.898876  0.993228  0.943700       886
# ...
