# %%
cd MoEv/
# Out:
# /home/jovyan/MoEv

# %%
"OC-SVM and iForest classifiers tested using D2"
# Out:
# 'OC-SVM and iForest classifiers tested using D2'

# %%
# !python3 -W ignore Start.py -t netflow && sed -i "s/D2_escaneoYSql_PCA.csv/D4_testProduccion_PCA.csv/g" ./conf.yaml && sed -i "s/dorothea/redcayle/g" ./conf.yaml
# Out:
# 2023-09-08 08:25:55,912: INFO - Moev.py started
#
#
# 			IsolationForest.joblib
#
#
#
# Accuracy for model is: 0.494808
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0   0.497310  0.959761  0.655148      7704
#            1   0.425926  0.029855  0.055798      7704
#
#     accuracy                       0.494808     15408
#    macro avg   0.461618  0.494808  0.355473     15408
# weighted avg   0.461618  0.494808  0.355473     15408
#
#
# Confusion Matrix:
#
# [[7394  310]
#  [7474  230]]
# ##########################################################
#
#
# 			OneClassSVM.joblib
#
#
#
# Accuracy for model is: 0.935813
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0   0.954761  0.914979  0.934447      7704
#            1   0.918380  0.956646  0.937123      7704
#
#     accuracy                       0.935813     15408
#    macro avg   0.936570  0.935813  0.935785     15408
# ...

# %%
"OC-SVM and iForest classifiers tested using D4"
# Out:
# 'OC-SVM and iForest classifiers tested using D4'

# %%
# !python3 -W ignore Start.py -t netflow && sed -i  "s/D4_testProduccion_PCA.csv/D2_escaneoYSql_PCA_Unbalanced.csv/g" ./conf.yaml && sed -i "s/redcayle/dorothea/g" ./conf.yaml
# Out:
# 2023-09-08 08:26:34,330: INFO - Moev.py started
#
#
# 			IsolationForest.joblib
#
#
#
# Accuracy for model is: 0.509783
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0   0.846154  0.023913  0.046512       460
#            1   0.504961  0.995652  0.670080       460
#
#     accuracy                       0.509783       920
#    macro avg   0.675558  0.509783  0.358296       920
# weighted avg   0.675558  0.509783  0.358296       920
#
#
# Confusion Matrix:
#
# [[ 11 449]
#  [  2 458]]
# ##########################################################
#
#
# 			OneClassSVM.joblib
#
#
#
# Accuracy for model is: 0.916304
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0   0.992288  0.839130  0.909305       460
#            1   0.860640  0.993478  0.922301       460
#
#     accuracy                       0.916304       920
#    macro avg   0.926464  0.916304  0.915803       920
# ...

# %%
"OC-SVM and iForest classifiers tested using unbalanced D2 99% benign 1% malicious"
# Out:
# 'OC-SVM and iForest classifiers tested using unbalanced D2 99% benign 1% malicious'

# %%
# !python3 -W ignore Start.py -t netflow  && sed -i  "s/D2_escaneoYSql_PCA_Unbalanced.csv/D4_testProduccion__unbalancedPCA.csv/g" ./conf.yaml && sed -i "s/dorothea/redcayle/g" ./conf.yaml
# Out:
# 2023-09-08 08:28:04,788: INFO - Moev.py started
#
#
# 			IsolationForest.joblib
#
#
#
# Accuracy for model is: 0.950514
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0   0.989958  0.959761  0.974626      7704
#            1   0.003215  0.013158  0.005168        76
#
#     accuracy                       0.950514      7780
#    macro avg   0.496587  0.486460  0.489897      7780
# weighted avg   0.980319  0.950514  0.965156      7780
#
#
# Confusion Matrix:
#
# [[7394  310]
#  [  75    1]]
# ##########################################################
#
#
# 			OneClassSVM.joblib
#
#
#
# Accuracy for model is: 0.915296
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0   0.999433  0.914979  0.955343      7704
#            1   0.099037  0.947368  0.179328        76
#
#     accuracy                       0.915296      7780
#    macro avg   0.549235  0.931174  0.567335      7780
# ...

# %%
"OC-SVM and iForest classifiers tested using unbalanced D4 99% benign 1% malicious"
# Out:
# 'OC-SVM and iForest classifiers tested using unbalanced D4 99% benign 1% malicious'

# %%
# !python3 -W ignore Start.py -t netflow
# Out:
# 2023-09-08 08:30:21,239: INFO - Moev.py started
#
#
# 			IsolationForest.joblib
#
#
#
# Accuracy for model is: 0.034409
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0   1.000000  0.023913  0.046709       460
#            1   0.011013  1.000000  0.021786         5
#
#     accuracy                       0.034409       465
#    macro avg   0.505507  0.511957  0.034248       465
# weighted avg   0.989366  0.034409  0.046441       465
#
#
# Confusion Matrix:
#
# [[ 11 449]
#  [  0   5]]
# ##########################################################
#
#
# 			OneClassSVM.joblib
#
#
#
# Accuracy for model is: 0.840860
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0   1.000000  0.839130  0.912530       460
#            1   0.063291  1.000000  0.119048         5
#
#     accuracy                       0.840860       465
#    macro avg   0.531646  0.919565  0.515789       465
# ...
