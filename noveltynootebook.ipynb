# %%
cd MoEv/

# %%
"OC-SVM and iForest classifiers tested using D2"
# Out:
# 'OC-SVM and iForest classifiers tested using D2'

# %%
# !python3 -W ignore Start.py -t netflow && sed -i "s/D2_escaneoYSql_PCA.csv/D4_testProduccion_PCA.csv/g" ./conf.yaml && sed -i "s/dorothea/redcayle/g" ./conf.yaml

# %%
"OC-SVM and iForest classifiers tested using D4"

# %%
# !python3 -W ignore Start.py -t netflow && sed -i  "s/D4_testProduccion_PCA.csv/D2_escaneoYSql_Unbalanced_PCA.csv/g" ./conf.yaml && sed -i "s/redcayle/dorothea/g" ./conf.yaml
# Out:
# 2023-09-07 09:09:21,664: INFO - Moev.py started
#
#
# 			OneClassSVM.joblib
#
#
#
# Accuracy for model is: 0.916304
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0   0.992288  0.839130  0.909305       460
#            1   0.860640  0.993478  0.922301       460
#
#     accuracy                       0.916304       920
#    macro avg   0.926464  0.916304  0.915803       920
# weighted avg   0.926464  0.916304  0.915803       920
#
#
# Confusion Matrix:
#
# [[386  74]
#  [  3 457]]
# ##########################################################
#
#
# 			IsolationForest.joblib
#
#
#
# Accuracy for model is: 0.509783
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0   0.846154  0.023913  0.046512       460
#            1   0.504961  0.995652  0.670080       460
#
#     accuracy                       0.509783       920
#    macro avg   0.675558  0.509783  0.358296       920
# weighted avg   0.675558  0.509783  0.358296       920
#
#
# Confusion Matrix:
#
# [[ 11 449]
#  [  2 458]]
# ##########################################################

# %%
"OC-SVM and iForest classifiers tested using unbalanced D2 99% benign 1% malicious"
# Out:
# 'OC-SVM and iForest classifiers tested using unbalanced D2 99% benign 1% malicious'

# %%
# !python3 -W ignore Start.py -t netflow
# Out:
# 2023-09-07 09:09:38,161: INFO - Moev.py started
#
#
# 			OneClassSVM.joblib
#
#
#
# Accuracy for model is: 0.914267
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0   0.998301  0.914979  0.954826      7704
#            1   0.089013  0.842105  0.161006        76
#
#     accuracy                       0.914267      7780
#    macro avg   0.543657  0.878542  0.557916      7780
# weighted avg   0.989418  0.914267  0.947071      7780
#
#
# Confusion Matrix:
#
# [[7049  655]
#  [  12   64]]
# ##########################################################
#
#
# 			IsolationForest.joblib
#
#
#
# Accuracy for model is: 0.950900
#
# Classification report:
#
#               precision    recall  f1-score   support
#
#            0   0.990356  0.959761  0.974819      7704
#            1   0.012739  0.052632  0.020513        76
#
#     accuracy                       0.950900      7780
#    macro avg   0.501548  0.506196  0.497666      7780
# weighted avg   0.980806  0.950900  0.965496      7780
#
#
# Confusion Matrix:
#
# [[7394  310]
#  [  72    4]]
# ##########################################################
